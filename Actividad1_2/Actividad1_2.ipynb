# %% [markdown]
# <a href="https://colab.research.google.com/github/MaferLedmar/Actividad1_ExtraccionDatos/blob/main/Actividad1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
#cargar archivo
from google.colab import files
files.upload()

# %%
df =pd.read_excel('Datos de Facturación.xlsx')
df.head()

# %%
#cambiar de str a float
df["CVE_CLPV"] = df["CVE_CLPV"].astype(float)

# %%
df["CVE_CLPV"] = df["CVE_CLPV"].replace({'':'0'}, regex = False)

# %%
df1 = df.copy()
df1.head()
# Out:
#   CVE_DOC  CVE_CLPV STATUS  CVE_VEND           FECHAELAB  FECHA_DOC  \
# 0  F29414    2465.0      C       1.0 2019-09-03 08:58:42 2019-09-03
# 1  F29415    3926.0      C       1.0 2019-09-03 09:55:14 2019-09-03
# 2  F29416    3926.0      C       1.0 2019-09-03 13:25:33 2019-09-03
# 3  F29417    3926.0      C       1.0 2019-09-03 13:33:23 2019-09-03
# 4  F29418    6813.0      C       2.0 2019-09-03 14:23:45 2019-09-03
#
#              FECHA_ENT  FECHA_VEN FECHA_CANCELA  CAN_TOT  DES_TOT  DES_FIN
# 0  2019-09-03 00:00:00 2019-09-18    2019-09-04  3980.00      0.0      0.0
# 1  2019-09-03 00:00:00 2019-10-03    2019-09-03  1550.00      0.0      0.0
# 2  2019-09-03 00:00:00 2019-10-03    2019-09-03  1550.00      0.0      0.0
# 3  2019-09-03 00:00:00 2019-10-03    2019-09-17  1550.00      0.0      0.0
# 4  2019-09-03 00:00:00 2019-09-03    2019-09-10  2435.44      0.0      0.0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10895 entries, 0 to 10894
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CVE_DOC        10890 non-null  object
#  1   CVE_CLPV       10895 non-null  float64
#  2   STATUS         10886 non-null  object
#  3   CVE_VEND       10847 non-null  float64
#  4   FECHAELAB      10893 non-null  datetime64[ns]
#  5   FECHA_DOC      10894 non-null  datetime64[ns]
#  6   FECHA_ENT      10893 non-null  object
#  7   FECHA_VEN      10895 non-null  datetime64[ns]
#  8   FECHA_CANCELA  358 non-null    datetime64[ns]
#  9   CAN_TOT        10889 non-null  float64
#  10  DES_TOT        10894 non-null  float64
#  11  DES_FIN        10892 non-null  float64
# dtypes: datetime64[ns](4), float64(5), object(3)
# memory usage: 1021.5+ KB

# %%
# CVE_CLPV, valores: 1000 a 2000
filtro1 =df1[(df1["CVE_CLPV"] >=1000) & (df1["CVE_CLPV"] <=2000)]
filtro1

# %%
# CVE_VEND, todas las claves excepto "4" y "5"
filtro2 = df1[~(df1['CVE_VEND'] == 4) & ~(df1["CVE_VEND"] == 5)]
filtro2

# %%
# 3- FECHA_ENT - fechas de "28/02/2022"
df1['FECHA_ENT']=df1['FECHA_ENT'].astype(str)

filtro3 = df1[df1['FECHA_ENT'] == "2022-02-28 00:00:00"]
filtro3

# %%
#4- CAN_TOT -Cantidades menores a 5951.7 o STATUS("E")
filtro4 = df1[(df1['CAN_TOT']<595.7) | (df1['STATUS'] == "E")]
filtro4

# %%
#5 Solo las columnas CVE_DOC, FECHA_ENT, FECHA_VEN, CAN_TOT
filtro5 = df1[["CVE_DOC", "FECHA_ENT", "FECHA_VEN", "CAN_TOT"]]
filtro5

# %%
#6 Solo las filas 7001 a 7099
filtro6 = df1.iloc[7001:7100, :]
filtro6

# %%
#7 Index = CVE_VEND (valores 1,2) (columna = FECHAELAB)
df1 =pd.read_excel('Datos de Facturación.xlsx', index_col= "CVE_VEND")
#df1.head()
filtro7 = df1.loc[[1, 2], ["FECHAELAB"]]
filtro7
# Out:
#                        FECHAELAB
# CVE_VEND
# 1.0      2019-09-03 08:58:42.000
# 1.0      2019-09-03 09:55:14.000
# 1.0      2019-09-03 13:25:33.000
# 1.0      2019-09-03 13:33:23.000
# 1.0      2019-09-04 09:15:12.000
# ...                          ...
# 2.0      2023-03-06 16:09:39.013
# 2.0      2023-03-06 16:38:42.933
# 2.0      2023-03-06 17:02:33.390
# 2.0      2023-03-07 12:43:49.567
# 2.0      2023-03-07 12:45:58.407
#
# [8665 rows x 1 columns]

# %%
#convertir archivo filtrado a csv
filtro1.to_csv("Filtro1.csv")
filtro2.to_csv("Filtro2.csv")
filtro3.to_csv("Filtro3.csv")
filtro4.to_csv("Filtro4.csv")
filtro5.to_csv("Filtro5.csv")
filtro6.to_csv("Filtro6.csv")
filtro7.to_csv("Filtro7.csv")

# %%
#descargar archivo filtrado
files.download("Filtro1.csv")
files.download("Filtro2.csv")
files.download("Filtro3.csv")
files.download("Filtro4.csv")
files.download("Filtro5.csv")
files.download("Filtro6.csv")
files.download("Filtro7.csv")
